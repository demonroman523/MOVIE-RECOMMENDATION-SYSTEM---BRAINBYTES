# %%
import pandas as pd
import os

# Set folder
folder = r"C:\Users\dhruv\movie recommendation system"
os.chdir(folder)

# Load original CSV
df = pd.read_csv("movies.csv")

# Combine text features (overview + genres)
df["combined"] = df["overview"].fillna("") + " " + df["genres"].fillna("")

# Save processed CSV
df.to_csv("movies_processed.csv", index=False)

print("✅ movies_processed.csv created!")
# Out:
# ✅ movies_processed.csv created!
